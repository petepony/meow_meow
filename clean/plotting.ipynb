# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("baseline5.csv", index_col=0)

# %%
df.head()
# Out:
#    mean_logtime  shift_std  alpha_time  spread_skew  order_mean  beta_time  \
# 0      0.943416   0.006898    0.050380     0.026382    0.022148   0.174265
# 1      0.982827   0.008493    0.096677     0.080775    0.007390   0.845970
# 2      0.994824   0.007234    0.989200     0.019015    0.021316   0.985355
# 3      0.990192   0.007062    0.796320     0.043633    0.095781   0.531626
# 4      0.986450   0.014763    0.940945     0.028323    0.109210   0.968397
#
#    spread_kurt  book_kurt  order_std  score_int  ...  log_volume  shift_ratio  \
# 0     0.010011   0.007629   0.015094   0.090033  ...    0.035063     0.593180
# 1     0.010885   0.007387   0.007865   0.015705  ...    0.102071     0.812863
# 2     0.010236   0.006981   0.013535   0.033657  ...    0.039368     0.991944
# 3     0.010438   0.007096   0.041700   0.007875  ...    0.018559     0.965184
# 4     0.008786   0.013284   0.043204   0.011630  ...    0.307853     0.690482
#
# ...

# %%
y = df.target
x = df.drop("target", axis=1)

# %% [markdown]
# ## Pomysły

# %%
## histogramy
## heatmapa korelacji pomiedzy wszystkimi features
## histogram roznicy miedzy sigma i target
## scatter ploty
## histogram bledow po zrobieniu modelu
## scatterplot guessow i targetow
## scatterplot xgb, regresji liniowej guessow i targetow
