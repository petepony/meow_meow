# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import fastparquet

# %%
target = pd.read_csv("optiver/train.csv")

# %%
trdf = pd.read_parquet("optiver/trade_train.parquet", engine = 'fastparquet')

# %%
bkdf = pd.read_parquet('optiver/book_train.parquet', engine = 'fastparquet')

# %%
#kernel dead

df = pd.merge(trdf, bkdf, how='inner', on = ['stock_id', 'time_id','seconds_in_bucket'])
len(trdf) - len(df)

# %%
example = pd.DataFrame({'a': [1, 2, 3]})

# %%
example.reset_index(inplace = True)

# %%
print(example)
# Out:
#    index  a
# 0      0  1
# 1      1  2
# 2      2  3

# %%
trdf0 = trdf.head(10000)
bkdf0 = bkdf.head(100000)

# %%
pd.merge(trdf0, bkdf0, how='inner', on = ['stock_id', 'time_id','seconds_in_bucket'])

# %%
bkdf.head()
# Out:
#    time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  ask_price2  \
# 0        5                  0    1.001422    1.002301     1.00137    1.002353
# 1        5                  1    1.001422    1.002301     1.00137    1.002353
# 2        5                  5    1.001422    1.002301     1.00137    1.002405
# 3        5                  6    1.001422    1.002301     1.00137    1.002405
# 4        5                  7    1.001422    1.002301     1.00137    1.002405
#
#    bid_size1  ask_size1  bid_size2  ask_size2 stock_id
# 0          3        226          2        100        0
# 1          3        100          2        100        0
# 2          3        100          2        100        0
# 3          3        126          2        100        0
# 4          3        126          2        100        0
